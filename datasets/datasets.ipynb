# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("adarshsingh0903/legal-dataset-sc-judgments-india-19502024")

print("Path to dataset files:", path)
# Out:
# Resuming download from 4467982336 bytes (2404209959 bytes left)...
# Resuming download from https://www.kaggle.com/api/v1/datasets/download/adarshsingh0903/legal-dataset-sc-judgments-india-19502024?dataset_version_number=1 (4467982336/6872192295) bytes left.
# 100%|██████████| 6.40G/6.40G [12:43<00:00, 3.15MB/s]
# Extracting files...
# Path to dataset files: C:\Users\kiran\.cache\kagglehub\datasets\adarshsingh0903\legal-dataset-sc-judgments-india-19502024\versions\1

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("keyushnisar/legal-docu")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 790k/790k [00:11<00:00, 70.8kB/s]
# Extracting files...
# Path to dataset files: C:\Users\kiran\.cache\kagglehub\datasets\keyushnisar\legal-docu\versions\3

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("nandr39/the-code-of-criminal-procedure-dataset-crpc")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 162k/162k [00:00<00:00, 220kB/s]
# Extracting files...
# Path to dataset files: C:\Users\kiran\.cache\kagglehub\datasets\nandr39\the-code-of-criminal-procedure-dataset-crpc\versions\1

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("harshit804/ipc-data")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 10.4M/10.4M [00:18<00:00, 584kB/s]
# Extracting files...
# Path to dataset files: C:\Users\kiran\.cache\kagglehub\datasets\harshit804\ipc-data\versions\2

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("veerchheda/civilsum-indian-legal-document-summarisation")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 85.3M/85.3M [00:30<00:00, 2.97MB/s]
# Extracting files...
# Path to dataset files: C:\Users\kiran\.cache\kagglehub\datasets\veerchheda\civilsum-indian-legal-document-summarisation\versions\1

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("sharathshebbar/indian-constitution")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 98.1k/98.1k [00:00<00:00, 139kB/s]
# Extracting files...
# Path to dataset files: C:\Users\kiran\.cache\kagglehub\datasets\sharathshebbar\indian-constitution\versions\1
